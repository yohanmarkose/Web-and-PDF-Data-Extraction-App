# %%
import pymupdf

# %%
import os
print(os.getcwd())  # Check current working directory
# Out:
# c:\Users\yohan\OneDrive\Documents\Yohan\MASTERS\Classes\DAMG 7245\Assignments\DAMG7245_Assignment01

# %%
doc = pymupdf.open("Prototypes/open_source_samples/pdf/covid_impact.pdf")

# %%
doc.page_count
# Out:
# 26

# %%
links = []
for page in doc.pages():
    links.append(page.get_links())
links
# Out:
# [[],
#  [],
#  [{'kind': 4,
#    'xref': 116,
#    'from': Rect(136.03900146484375, 182.3690185546875, 142.50100708007812, 194.40899658203125),
#    'page': 2,
#    'to': Point(87.243, 114.116),
#    'zoom': 0.0,
#    'nameddest': 'Hfootnote.1',
#    'id': ''},
#   {'kind': 4,
#    'xref': 117,
#    'from': Rect(428.57000732421875, 580.9559936523438, 435.0320129394531, 592.9959716796875),
#    'page': 2,
#    'to': Point(87.243, 95.147),
#    'zoom': 0.0,
#    'nameddest': 'Hfootnote.2',
#    'id': ''},
#   {'kind': 2,
#    'xref': 118,
#    'from': Rect(209.16799926757812, 679.68701171875, 459.0580139160156, 690.3369750976562),
#    'uri': 'https://www.nytimes.com/2020/04/15/us/coronavirus-colleges-universities-admissions.html',
#    'id': ''}],
#  [{'kind': 4,
#    'xref': 120,
#    'from': Rect(124.49800109863281, 112.71502685546875, 130.9600067138672, 124.7550048828125),
#    'page': 3,
#    'to': Point(87.243, 125.919),
#    'zoom': 0.0,
#    'nameddest': 'Hfootnote.3',
# ...
